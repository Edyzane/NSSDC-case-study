# %%
import warnings
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'png' #retina
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
from scipy.stats import skew,norm
from scipy.stats.stats import pearsonr
import missingno as msno
from IPython.display import display
pd.options.display.max_columns = None

# %%
df = pd.read_csv("cs1_part1_res.csv")

# %%
df.head()
# Out:
#          pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1       Feedr        Norm      1Fam      1Story             5             6
# 2        Norm        Norm      1Fam      1Story             6             6
# 3        Norm        Norm      1Fam      1Story             7             5
# 4        Norm        Norm      1Fam      2Story             5             5
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1960            1960        Hip   CompShg      BrkFace      Plywood
# 1        1961            1961      Gable   CompShg      VinylSd      VinylSd
# 2        1958            1958        Hip   CompShg      Wd Sdng      Wd Sdng
# 3        1968            1968        Hip   CompShg      BrkFace      BrkFace
# 4        1997            1998      Gable   CompShg      VinylSd      VinylSd
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0        Stone         112.0         TA         TA     CBlock        TA
# 1         None           0.0         TA         TA     CBlock        TA
# 2      BrkFace         108.0         TA         TA     CBlock        TA
# 3         None           0.0         Gd         TA     CBlock        TA
# 4         None           0.0         TA         TA      PConc        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        Gd            Gd            BLQ         639.0            Unf
# 1        TA            No            Rec         468.0            LwQ
# 2        TA            No            ALQ         923.0            Unf
# 3        TA            No            ALQ        1065.0            Unf
# 4        TA            No            GLQ         791.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0           0.0        441.0         1080.0    GasA         Fa           Y
# 1         144.0        270.0          882.0    GasA         TA           Y
# 2           0.0        406.0         1329.0    GasA         TA           Y
# 3           0.0       1045.0         2110.0    GasA         Ex           Y
# 4           0.0        137.0          928.0    GasA         Gd           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      SBrkr        1656           0                0         1656
# 1      SBrkr         896           0                0          896
# 2      SBrkr        1329           0                0         1329
# 3      SBrkr        2110           0                0         2110
# 4      SBrkr         928         701                0         1629
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0             1.0             0.0          1          0              3
# 1             0.0             0.0          1          0              2
# 2             0.0             0.0          1          1              3
# 3             1.0             0.0          2          1              3
# 4             0.0             0.0          2          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              1           TA              7        Typ           2
# 1              1           TA              5        Typ           0
# 2              1           Gd              6        Typ           0
# 3              1           Ex              8        Typ           2
# 4              1           TA              6        Typ           1
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0           Gd      Attchd         1960.0           Fin          2.0
# 1          NaN      Attchd         1961.0           Unf          1.0
# 2          NaN      Attchd         1958.0           Unf          1.0
# 3           TA      Attchd         1968.0           Fin          2.0
# 4           TA      Attchd         1997.0           Fin          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0        528.0          TA          TA           P           210
# 1        730.0          TA          TA           Y           140
# 2        312.0          TA          TA           Y           393
# 3        522.0          TA          TA           Y             0
# 4        482.0          TA          TA           Y           212
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             62               0           0             0          0     NaN
# 1              0               0           0           120          0     NaN
# 2             36               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             34               0           0             0          0     NaN
#
#    fence misc_feature  misc_val  mo_sold  yr_sold sale_type sale_condition  \
# 0    NaN          NaN         0        5     2010       WD          Normal
# 1  MnPrv          NaN         0        6     2010       WD          Normal
# 2    NaN         Gar2     12500        6     2010       WD          Normal
# 3    NaN          NaN         0        4     2010       WD          Normal
# 4  MnPrv          NaN         0        3     2010       WD          Normal
#
#    saleprice
# 0  12.278398
# 1  11.561725
# 2  12.055256
# 3  12.404928
# 4  12.154258

# %%
#visualize missing data
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
print("df size is : {}".format(df.shape))
missingdf = (df.isnull().sum() / len(df)) * 100
missingdf = missingdf.drop(missingdf[missingdf == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :missingdf})
missing_data.head(20)
# Out:
# df size is : (2916, 81)
#                 Missing Ratio
# pool_qc             99.622771
# misc_feature        96.433471
# alley               93.244170
# fence               80.486968
# fireplace_qu        48.696845
# lot_frontage        16.735254
# garage_yr_blt        5.452675
# garage_cond          5.452675
# garage_qual          5.452675
# garage_finish        5.452675
# garage_type          5.384088
# bsmt_exposure        2.812071
# bsmtfin_type_2       2.743484
# bsmtfin_type_1       2.709191
# bsmt_qual            2.709191
# bsmt_cond            2.709191
# mas_vnr_type         0.788752
# mas_vnr_area         0.788752
# garage_cars          0.034294
# bsmtfin_sf_2         0.034294

# %% [markdown]
# # remove unnecessary features

# %%
#remove the column PID, not usefull features
df = df.drop("pid",axis=1)

# %%
#remove utilities because the data mostly is the same only 3 entry is different
df = df.drop(['utilities'], axis=1)

# %% [markdown]
# # input missing values
#
# is added based on the description notes

# %%
msno.matrix(df.select_dtypes(include='object'))
# Out:
# <AxesSubplot:>

# %%
#object type
df_objs = df.select_dtypes(include='object')
df_objs
# Out:
#      ms_zoning street alley lot_shape land_contour lot_config land_slope  \
# 0           RL   Pave   NaN       IR1          Lvl     Corner        Gtl
# 1           RH   Pave   NaN       Reg          Lvl     Inside        Gtl
# 2           RL   Pave   NaN       IR1          Lvl     Corner        Gtl
# 3           RL   Pave   NaN       Reg          Lvl     Corner        Gtl
# 4           RL   Pave   NaN       IR1          Lvl     Inside        Gtl
# ...        ...    ...   ...       ...          ...        ...        ...
# 2911        RL   Pave   NaN       IR1          Lvl    CulDSac        Gtl
# 2912        RL   Pave   NaN       IR1          Low     Inside        Mod
# 2913        RL   Pave   NaN       Reg          Lvl     Inside        Gtl
# 2914        RL   Pave   NaN       Reg          Lvl     Inside        Mod
# 2915        RL   Pave   NaN       Reg          Lvl     Inside        Mod
#
#      neighborhood condition_1 condition_2 bldg_type house_style roof_style  \
# 0           NAmes        Norm        Norm      1Fam      1Story        Hip
# 1           NAmes       Feedr        Norm      1Fam      1Story      Gable
# 2           NAmes        Norm        Norm      1Fam      1Story        Hip
# 3           NAmes        Norm        Norm      1Fam      1Story        Hip
# 4         Gilbert        Norm        Norm      1Fam      2Story      Gable
# ...           ...         ...         ...       ...         ...        ...
# 2911      Mitchel        Norm        Norm      1Fam        SLvl      Gable
# 2912      Mitchel        Norm        Norm      1Fam      1Story      Gable
# 2913      Mitchel        Norm        Norm      1Fam      SFoyer      Gable
# 2914      Mitchel        Norm        Norm      1Fam      1Story      Gable
# 2915      Mitchel        Norm        Norm      1Fam      2Story      Gable
#
#      roof_matl exterior_1st exterior_2nd mas_vnr_type exter_qual exter_cond  \
# 0      CompShg      BrkFace      Plywood        Stone         TA         TA
# 1      CompShg      VinylSd      VinylSd         None         TA         TA
# 2      CompShg      Wd Sdng      Wd Sdng      BrkFace         TA         TA
# 3      CompShg      BrkFace      BrkFace         None         Gd         TA
# 4      CompShg      VinylSd      VinylSd         None         TA         TA
# ...        ...          ...          ...          ...        ...        ...
# 2911   CompShg      HdBoard      HdBoard         None         TA         TA
# 2912   CompShg      HdBoard      HdBoard         None         TA         TA
# 2913   CompShg      HdBoard      Wd Shng         None         TA         TA
# 2914   CompShg      HdBoard      HdBoard         None         TA         TA
# 2915   CompShg      HdBoard      HdBoard      BrkFace         TA         TA
#
#      foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 0        CBlock        TA        Gd            Gd            BLQ
# 1        CBlock        TA        TA            No            Rec
# 2        CBlock        TA        TA            No            ALQ
# 3        CBlock        TA        TA            No            ALQ
# 4         PConc        Gd        TA            No            GLQ
# ...         ...       ...       ...           ...            ...
# 2911     CBlock        TA        TA            Av            GLQ
# 2912     CBlock        Gd        TA            Av            BLQ
# 2913      PConc        Gd        TA            Av            GLQ
# 2914     CBlock        Gd        TA            Av            ALQ
# 2915      PConc        Gd        TA            Av            LwQ
#
#      bsmtfin_type_2 heating heating_qc central_air electrical kitchen_qual  \
# 0               Unf    GasA         Fa           Y      SBrkr           TA
# 1               LwQ    GasA         TA           Y      SBrkr           TA
# 2               Unf    GasA         TA           Y      SBrkr           Gd
# 3               Unf    GasA         Ex           Y      SBrkr           Ex
# 4               Unf    GasA         Gd           Y      SBrkr           TA
# ...             ...     ...        ...         ...        ...          ...
# 2911            Unf    GasA         TA           Y      SBrkr           TA
# 2912            ALQ    GasA         TA           Y      SBrkr           TA
# 2913            Unf    GasA         TA           Y      SBrkr           TA
# 2914            LwQ    GasA         Gd           Y      SBrkr           TA
# 2915            Unf    GasA         Ex           Y      SBrkr           TA
#
#      functional fireplace_qu garage_type garage_finish garage_qual  \
# 0           Typ           Gd      Attchd           Fin          TA
# 1           Typ          NaN      Attchd           Unf          TA
# 2           Typ          NaN      Attchd           Unf          TA
# 3           Typ           TA      Attchd           Fin          TA
# 4           Typ           TA      Attchd           Fin          TA
# ...         ...          ...         ...           ...         ...
# 2911        Typ          NaN      Detchd           Unf          TA
# 2912        Typ          NaN      Attchd           Unf          TA
# 2913        Typ          NaN         NaN           NaN         NaN
# 2914        Typ           TA      Attchd           RFn          TA
# 2915        Typ           TA      Attchd           Fin          TA
#
#      garage_cond paved_drive pool_qc  fence misc_feature sale_type  \
# 0             TA           P     NaN    NaN          NaN       WD
# 1             TA           Y     NaN  MnPrv          NaN       WD
# 2             TA           Y     NaN    NaN         Gar2       WD
# 3             TA           Y     NaN    NaN          NaN       WD
# 4             TA           Y     NaN  MnPrv          NaN       WD
# ...          ...         ...     ...    ...          ...       ...
# 2911          TA           Y     NaN  GdPrv          NaN       WD
# 2912          TA           Y     NaN  MnPrv          NaN       WD
# 2913         NaN           Y     NaN  MnPrv         Shed       WD
# 2914          TA           Y     NaN    NaN          NaN       WD
# 2915          TA           Y     NaN    NaN          NaN       WD
#
#      sale_condition
# 0            Normal
# 1            Normal
# 2            Normal
# 3            Normal
# 4            Normal
# ...             ...
# 2911         Normal
# 2912         Normal
# 2913         Normal
# 2914         Normal
# 2915         Normal
#
# [2916 rows x 42 columns]

# %%
#i try to group them up into clusters with same values

#values "none"
for col in ('pool_qc','misc_feature','garage_type','alley','fence','fireplace_qu','garage_finish', 'garage_qual', 'garage_cond','mas_vnr_type','ms_subclass'):
    df[col] = df[col].fillna('None')

# %%
# For below categorical basement-related features, NaN means that there is no basement.
for col in ('bsmt_qual', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_type_2'):
    df[col] = df[col].fillna('None')

# %%
#MSZoning classification : 'RL' is common
df['ms_zoning'] = df['ms_zoning'].fillna(df['ms_zoning'].fillna("RL"))

# %%
df["functional"] = df["functional"].fillna("Typ")

# %%
# Electrical standard  = SBrkr
df['electrical'] = df['electrical'].fillna(df['electrical'].fillna("SBrkr"))

# %%
# KitchenQual
df['kitchen_qual'] = df['kitchen_qual'].fillna(df['kitchen_qual'].fillna("TA"))

# %%
# Exterior1st and Exterior2nd
df['exterior_1st'] = df['exterior_1st'].fillna(df['exterior_1st'].fillna('Other'))
df['exterior_2nd'] = df['exterior_2nd'].fillna(df['exterior_2nd'].fillna('Other'))

# %%
#SaleType
df['sale_type'] = df['sale_type'].fillna(df['sale_type'].fillna('Oth'))

# %%
msno.matrix(df.select_dtypes(include='object'))
# Out:
# <AxesSubplot:>

# %%
#integer type
df_objs = df.select_dtypes(exclude='object')
df_objs
# Out:
#       ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# 0              20         141.0     31770             6             5
# 1              20          80.0     11622             5             6
# 2              20          81.0     14267             6             6
# 3              20          93.0     11160             7             5
# 4              60          74.0     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2911           80          37.0      7937             6             6
# 2912           20           NaN      8885             5             5
# 2913           85          62.0     10441             5             5
# 2914           20          77.0     10010             5             5
# 2915           60          74.0      9627             7             5
#
#       year_built  year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  \
# 0           1960            1960         112.0         639.0           0.0
# 1           1961            1961           0.0         468.0         144.0
# 2           1958            1958         108.0         923.0           0.0
# 3           1968            1968           0.0        1065.0           0.0
# 4           1997            1998           0.0         791.0           0.0
# ...          ...             ...           ...           ...           ...
# 2911        1984            1984           0.0         819.0           0.0
# 2912        1983            1983           0.0         301.0         324.0
# 2913        1992            1992           0.0         337.0           0.0
# 2914        1974            1975           0.0        1071.0         123.0
# 2915        1993            1994          94.0         758.0           0.0
#
#       bsmt_unf_sf  total_bsmt_sf  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  \
# 0           441.0         1080.0        1656           0                0
# 1           270.0          882.0         896           0                0
# 2           406.0         1329.0        1329           0                0
# 3          1045.0         2110.0        2110           0                0
# 4           137.0          928.0         928         701                0
# ...           ...            ...         ...         ...              ...
# 2911        184.0         1003.0        1003           0                0
# 2912        239.0          864.0         902           0                0
# 2913        575.0          912.0         970           0                0
# 2914        195.0         1389.0        1389           0                0
# 2915        238.0          996.0         996        1004                0
#
#       gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 0            1656             1.0             0.0          1          0
# 1             896             0.0             0.0          1          0
# 2            1329             0.0             0.0          1          1
# 3            2110             1.0             0.0          2          1
# 4            1629             0.0             0.0          2          1
# ...           ...             ...             ...        ...        ...
# 2911         1003             1.0             0.0          1          0
# 2912          902             1.0             0.0          1          0
# 2913          970             0.0             1.0          1          0
# 2914         1389             1.0             0.0          1          0
# 2915         2000             0.0             0.0          2          1
#
#       bedroom_abvgr  kitchen_abvgr  totrms_abvgrd  fireplaces  garage_yr_blt  \
# 0                 3              1              7           2         1960.0
# 1                 2              1              5           0         1961.0
# 2                 3              1              6           0         1958.0
# 3                 3              1              8           2         1968.0
# 4                 3              1              6           1         1997.0
# ...             ...            ...            ...         ...            ...
# 2911              3              1              6           0         1984.0
# 2912              2              1              5           0         1983.0
# 2913              3              1              6           0            NaN
# 2914              2              1              6           1         1975.0
# 2915              3              1              9           1         1993.0
#
#       garage_cars  garage_area  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0             2.0        528.0           210             62               0
# 1             1.0        730.0           140              0               0
# 2             1.0        312.0           393             36               0
# 3             2.0        522.0             0              0               0
# 4             2.0        482.0           212             34               0
# ...           ...          ...           ...            ...             ...
# 2911          2.0        588.0           120              0               0
# 2912          2.0        484.0           164              0               0
# 2913          0.0          0.0            80             32               0
# 2914          2.0        418.0           240             38               0
# 2915          3.0        650.0           190             48               0
#
#       3ssn_porch  screen_porch  pool_area  misc_val  mo_sold  yr_sold  \
# 0              0             0          0         0        5     2010
# 1              0           120          0         0        6     2010
# 2              0             0          0     12500        6     2010
# 3              0             0          0         0        4     2010
# 4              0             0          0         0        3     2010
# ...          ...           ...        ...       ...      ...      ...
# 2911           0             0          0         0        3     2006
# 2912           0             0          0         0        6     2006
# 2913           0             0          0       700        7     2006
# 2914           0             0          0         0        4     2006
# 2915           0             0          0         0       11     2006
#
#       saleprice
# 0     12.278398
# 1     11.561725
# 2     12.055256
# 3     12.404928
# 4     12.154258
# ...         ...
# 2911  11.867104
# 2912  11.782960
# 2913  11.790565
# 2914  12.043560
# 2915  12.144203
#
# [2916 rows x 37 columns]

# %%
msno.matrix(df.select_dtypes(exclude='object'))
# Out:
# <AxesSubplot:>

# %%
# Replacing missing data with 0 (Since No garage = no cars in such garage).
for col in ('garage_yr_blt', 'garage_area', 'garage_cars'):
    df[col] = df[col].fillna(0)

# %%
# missing values are likely zero for having no basement 
for col in ('bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf','total_bsmt_sf', 'bsmt_full_bath', 'bsmt_half_bath'):
    df[col] = df[col].fillna(0)

# %%
df["mas_vnr_area"] = df["mas_vnr_area"].fillna(0)

# %%
#Group by neighborhood and fill in missing value by the median LotFrontage of all the neighborhood
df["lot_frontage"] = df.groupby("neighborhood")["lot_frontage"].transform(lambda x: x.fillna(x.median()))

# %%
#there are still missing values for lot_frontage
#fill it with median
df["lot_frontage"] = df["lot_frontage"].fillna(df['lot_frontage'].median())

# %% [markdown]
# # some numeric are actually categorical

# %%
#dang need run this everytime i imported from csv...cos evertime imported in the astype changed back
# Transforming required numerical features to categorical

df['ms_subclass'] = df['ms_subclass'].astype(str)
df['overall_cond'] = df['overall_cond'].astype(str)
df['yr_sold'] = df['yr_sold'].astype(str)
df['mo_sold'] = df['mo_sold'].astype(str)

# %%
df['lot_frontage'].isnull().values.any()
# Out:
# False

# %%
msno.matrix(df.select_dtypes(exclude='object'))
# Out:
# <AxesSubplot:>

# %%
#list of features with missng values
listmiss = df.columns[df.isnull().any()].tolist()
listmiss
#df.columns[df.isnull().any()] #does the same 
#if empty..means no more
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ms_subclass      2916 non-null   object
#  1   ms_zoning        2916 non-null   object
#  2   lot_frontage     2916 non-null   float64
#  3   lot_area         2916 non-null   int64
#  4   street           2916 non-null   object
#  5   alley            2916 non-null   object
#  6   lot_shape        2916 non-null   object
#  7   land_contour     2916 non-null   object
#  8   lot_config       2916 non-null   object
#  9   land_slope       2916 non-null   object
#  10  neighborhood     2916 non-null   object
#  11  condition_1      2916 non-null   object
#  12  condition_2      2916 non-null   object
#  13  bldg_type        2916 non-null   object
#  14  house_style      2916 non-null   object
#  15  overall_qual     2916 non-null   int64
#  16  overall_cond     2916 non-null   object
#  17  year_built       2916 non-null   int64
#  18  year_remod/add   2916 non-null   int64
#  19  roof_style       2916 non-null   object
#  20  roof_matl        2916 non-null   object
#  21  exterior_1st     2916 non-null   object
#  22  exterior_2nd     2916 non-null   object
#  23  mas_vnr_type     2916 non-null   object
#  24  mas_vnr_area     2916 non-null   float64
#  25  exter_qual       2916 non-null   object
#  26  exter_cond       2916 non-null   object
#  27  foundation       2916 non-null   object
#  28  bsmt_qual        2916 non-null   object
#  29  bsmt_cond        2916 non-null   object
#  30  bsmt_exposure    2916 non-null   object
#  31  bsmtfin_type_1   2916 non-null   object
#  32  bsmtfin_sf_1     2916 non-null   float64
#  33  bsmtfin_type_2   2916 non-null   object
#  34  bsmtfin_sf_2     2916 non-null   float64
#  35  bsmt_unf_sf      2916 non-null   float64
#  36  total_bsmt_sf    2916 non-null   float64
#  37  heating          2916 non-null   object
#  38  heating_qc       2916 non-null   object
#  39  central_air      2916 non-null   object
#  40  electrical       2916 non-null   object
#  41  1st_flr_sf       2916 non-null   int64
#  42  2nd_flr_sf       2916 non-null   int64
#  43  low_qual_fin_sf  2916 non-null   int64
#  44  gr_liv_area      2916 non-null   int64
#  45  bsmt_full_bath   2916 non-null   float64
#  46  bsmt_half_bath   2916 non-null   float64
#  47  full_bath        2916 non-null   int64
#  48  half_bath        2916 non-null   int64
#  49  bedroom_abvgr    2916 non-null   int64
#  50  kitchen_abvgr    2916 non-null   int64
#  51  kitchen_qual     2916 non-null   object
#  52  totrms_abvgrd    2916 non-null   int64
#  53  functional       2916 non-null   object
#  54  fireplaces       2916 non-null   int64
#  55  fireplace_qu     2916 non-null   object
#  56  garage_type      2916 non-null   object
#  57  garage_yr_blt    2916 non-null   float64
#  58  garage_finish    2916 non-null   object
#  59  garage_cars      2916 non-null   float64
#  60  garage_area      2916 non-null   float64
#  61  garage_qual      2916 non-null   object
#  62  garage_cond      2916 non-null   object
#  63  paved_drive      2916 non-null   object
#  64  wood_deck_sf     2916 non-null   int64
#  65  open_porch_sf    2916 non-null   int64
#  66  enclosed_porch   2916 non-null   int64
#  67  3ssn_porch       2916 non-null   int64
#  68  screen_porch     2916 non-null   int64
#  69  pool_area        2916 non-null   int64
#  70  pool_qc          2916 non-null   object
#  71  fence            2916 non-null   object
#  72  misc_feature     2916 non-null   object
#  73  misc_val         2916 non-null   int64
#  74  mo_sold          2916 non-null   object
#  75  yr_sold          2916 non-null   object
#  76  sale_type        2916 non-null   object
#  77  sale_condition   2916 non-null   object
#  78  saleprice        2916 non-null   float64
# dtypes: float64(12), int64(21), object(46)
# memory usage: 1.8+ MB

# %% [markdown]
# # save the files

# %%
df.to_csv("cs1_part2_res.csv",index=False)
