# %% [markdown]
# # imports

# %%
import warnings
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'png' #retina
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
from scipy.stats import skew,norm
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv("Ames_Housing_Data.csv")

# %% [markdown]
# # change features name to lowercase and spaces to underscore, edited to ease during deployment and convenient sake

# %%
# Make column labels lowercase
df.columns = map(str.lower, df.columns)

# Replace spaces in columns with underscore
df.columns = df.columns.str.replace('\s+', '_')

# %%
df.head()
# Out:
#          pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   lot_shape land_contour utilities  ... pool_area pool_qc  fence misc_feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
#   misc_val mo_sold yr_sold  sale_type  sale_condition  saleprice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
# 2    12500       6    2010        WD           Normal     172000
# 3        0       4    2010        WD           Normal     244000
# 4        0       3    2010        WD           Normal     189900
#
# [5 rows x 81 columns]

# %%
print('Data: \n')
print("Number of columns: "+ str(df.shape[1]))
print("Number of rows: "+ str(df.shape[0]))
# Out:
# Data:
#
# Number of columns: 81
# Number of rows: 2930

# %%
df.info()

# %%
df['saleprice'].describe()

# %%
# Kernel Density Plot
sns.distplot(df.saleprice,fit=norm);
plt.ylabel=('Frequency')
plt.title=('SalePrice distribution');

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['saleprice']);

print("skewness: %f" % df['saleprice'].skew());
# Out:
# skewness: 1.743500

# %%
fig = plt.figure()
res = stats.probplot(df['saleprice'], plot=plt)
plt.show()

# %%
#since it is right skewed we will use log transformation
#https://gdcoder.com/when-why-to-use-log-transformation-in-regression/

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#df.corr()['SalePrice'].sort_values()
a =df.corr()['saleprice'].sort_values(ascending =False).head(10)

print(a)
#print(df.info())
# Out:
# saleprice         1.000000
# overall_qual      0.799262
# gr_liv_area       0.706780
# garage_cars       0.647877
# garage_area       0.640401
# total_bsmt_sf     0.632280
# 1st_flr_sf        0.621676
# year_built        0.558426
# full_bath         0.545604
# year_remod/add    0.532974
# Name: saleprice, dtype: float64

# %%
df.head()
# Out:
#          pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   lot_shape land_contour utilities  ... pool_area pool_qc  fence misc_feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
#   misc_val mo_sold yr_sold  sale_type  sale_condition  saleprice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
# 2    12500       6    2010        WD           Normal     172000
# 3        0       4    2010        WD           Normal     244000
# 4        0       3    2010        WD           Normal     189900
#
# [5 rows x 81 columns]

# %%
#how do we plan to fix skewness?
#remove all outliers or using sqrt/log/box cox
#https://medium.com/@ODSC/transforming-skewed-data-for-machine-learning-90e6cc364b0

# %%
#features with categorical dont touch!!
#features with numerical, or ordinal..yes ..try check

# %% [markdown]
# # fixing outliers

# %%
#overall_qual
#doesnt make sense to remove any of the data!!

#box plot overallqual/saleprice
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='overall_qual',y='saleprice')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='overall_qual',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='overall_qual', ylabel='saleprice'>

# %%
#gr_liv_area
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['gr_liv_area'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='gr_liv_area',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='gr_liv_area', ylabel='saleprice'>

# %%
#remove using visual aid
df = df.drop(df[(df['gr_liv_area']>4000) & (df['gr_liv_area']<400000)].index)

# %%
#garage_cars
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='garage_cars',y='saleprice')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='garage_cars',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='garage_cars', ylabel='saleprice'>

# %%
#garage_area
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['garage_area'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='garage_area',y='saleprice',data=df)
plt.show()

# %%
#remove using visual aid
df = df.drop(df[(df['garage_area']>1200)].index)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='garage_area',y='saleprice',data=df)
plt.show()

# %%
#total_bsmt_sf
plt.figure(figsize=(12,8))
sns.scatterplot(x='total_bsmt_sf',y='saleprice',data=df)
plt.show()

# %%
#1st_flr_sf 
plt.figure(figsize=(12,8))
sns.scatterplot(x='1st_flr_sf',y='saleprice',data=df)
plt.show()

# %%
#remove using visual aid
df = df.drop(df[(df['1st_flr_sf']>3500)].index)

# %%
#after
plt.figure(figsize=(12,8))
sns.scatterplot(x='1st_flr_sf',y='saleprice',data=df)
plt.show()

# %%
#year_built
plt.figure(figsize=(16,8))

sns.boxplot(data=df, x='year_built',y='saleprice')
plt.xticks(rotation=90)
plt.show()

# %%
#full_bath
plt.figure(figsize=(16,8))

sns.boxplot(data=df, x='full_bath',y='saleprice')
plt.show()

# %%
#year_remod/add
plt.figure(figsize=(16,8))

sns.boxplot(data=df, x='year_remod/add',y='saleprice')
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2916 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              2916 non-null   int64
#  1   ms_subclass      2916 non-null   int64
#  2   ms_zoning        2916 non-null   object
#  3   lot_frontage     2428 non-null   float64
#  4   lot_area         2916 non-null   int64
#  5   street           2916 non-null   object
#  6   alley            197 non-null    object
#  7   lot_shape        2916 non-null   object
#  8   land_contour     2916 non-null   object
#  9   utilities        2916 non-null   object
#  10  lot_config       2916 non-null   object
#  11  land_slope       2916 non-null   object
#  12  neighborhood     2916 non-null   object
#  13  condition_1      2916 non-null   object
#  14  condition_2      2916 non-null   object
#  15  bldg_type        2916 non-null   object
#  16  house_style      2916 non-null   object
#  17  overall_qual     2916 non-null   int64
#  18  overall_cond     2916 non-null   int64
#  19  year_built       2916 non-null   int64
#  20  year_remod/add   2916 non-null   int64
#  21  roof_style       2916 non-null   object
#  22  roof_matl        2916 non-null   object
#  23  exterior_1st     2916 non-null   object
#  24  exterior_2nd     2916 non-null   object
#  25  mas_vnr_type     2893 non-null   object
#  26  mas_vnr_area     2893 non-null   float64
#  27  exter_qual       2916 non-null   object
#  28  exter_cond       2916 non-null   object
#  29  foundation       2916 non-null   object
#  30  bsmt_qual        2837 non-null   object
#  31  bsmt_cond        2837 non-null   object
#  32  bsmt_exposure    2834 non-null   object
#  33  bsmtfin_type_1   2837 non-null   object
#  34  bsmtfin_sf_1     2915 non-null   float64
#  35  bsmtfin_type_2   2836 non-null   object
#  36  bsmtfin_sf_2     2915 non-null   float64
#  37  bsmt_unf_sf      2915 non-null   float64
#  38  total_bsmt_sf    2915 non-null   float64
#  39  heating          2916 non-null   object
#  40  heating_qc       2916 non-null   object
#  41  central_air      2916 non-null   object
#  42  electrical       2915 non-null   object
#  43  1st_flr_sf       2916 non-null   int64
#  44  2nd_flr_sf       2916 non-null   int64
#  45  low_qual_fin_sf  2916 non-null   int64
#  46  gr_liv_area      2916 non-null   int64
#  47  bsmt_full_bath   2915 non-null   float64
#  48  bsmt_half_bath   2915 non-null   float64
#  49  full_bath        2916 non-null   int64
#  50  half_bath        2916 non-null   int64
#  51  bedroom_abvgr    2916 non-null   int64
#  52  kitchen_abvgr    2916 non-null   int64
#  53  kitchen_qual     2916 non-null   object
#  54  totrms_abvgrd    2916 non-null   int64
#  55  functional       2916 non-null   object
#  56  fireplaces       2916 non-null   int64
#  57  fireplace_qu     1496 non-null   object
#  58  garage_type      2759 non-null   object
#  59  garage_yr_blt    2757 non-null   float64
#  60  garage_finish    2757 non-null   object
#  61  garage_cars      2915 non-null   float64
#  62  garage_area      2915 non-null   float64
#  63  garage_qual      2757 non-null   object
#  64  garage_cond      2757 non-null   object
#  65  paved_drive      2916 non-null   object
#  66  wood_deck_sf     2916 non-null   int64
#  67  open_porch_sf    2916 non-null   int64
#  68  enclosed_porch   2916 non-null   int64
#  69  3ssn_porch       2916 non-null   int64
#  70  screen_porch     2916 non-null   int64
#  71  pool_area        2916 non-null   int64
#  72  pool_qc          11 non-null     object
#  73  fence            569 non-null    object
#  74  misc_feature     104 non-null    object
#  75  misc_val         2916 non-null   int64
#  76  mo_sold          2916 non-null   int64
#  77  yr_sold          2916 non-null   int64
#  78  sale_type        2916 non-null   object
#  79  sale_condition   2916 non-null   object
#  80  saleprice        2916 non-null   int64
# dtypes: float64(11), int64(27), object(43)
# memory usage: 1.9+ MB

# %% [markdown]
# # fixing skewness

# %%
#log transform the data saleprice
#df["saleprice"] = np.log1p(df["saleprice"])

# %%
df['saleprice'].skew()
# Out:
# 1.5951816063706306

# %%
df["saleprice"] = np.log1p(df["saleprice"])

# %%
df['saleprice'].skew()
# Out:
# -0.04442897877435374

# %%
# Kernel Density Plot

sns.distplot(df.saleprice,fit=norm);
plt.ylabel=('Frequency')
plt.title=('SalePrice distribution');

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['saleprice']);

print("skewness: %f" % df['saleprice'].skew());
# Out:
# skewness: -0.044429

# %%
fig = plt.figure()
res = stats.probplot(df['saleprice'], plot=plt)
plt.show()

# %% [markdown]
# # save the model

# %%
df.to_csv('cs1_part1_res.csv',index=False)
